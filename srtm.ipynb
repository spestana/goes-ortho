# %%
# SRTM DEMs
# https://dds.cr.usgs.gov/srtm/version2_1/Documentation/SRTM_Topo.pdf

# %%
import rasterio as rio
import numpy as np
import matplotlib.pyplot as plt
import struct

# %%
n37_f = '/home/jovyan/srtm/n37w120.tif'
n38_f = '/home/jovyan/srtm/n38w120.tif'

# %%
file = rio.open(n37_f, 'r')
n37 = file.read()
n37 = n37[0,:,:]

file = rio.open(n38_f, 'r')
n38 = file.read()
n38 = n38[0,:,:]

# %%
fig, ax = plt.subplots()
ax.imshow(n38)
